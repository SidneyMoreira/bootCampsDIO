# %%
print('Olá mundo!!')
# Out:
# Olá mundo!!

# %%
print('Estou aprendendo Python')
# Out:
# Estou aprendendo Python

# %%
'Estou aprendendo'
# Out:
# 'Estou aprendendo'

# %%
1 + 1
# Out:
# 2

# %%
10 - 2
# Out:
# 8

# %%
#esse é comentário em Python

# %%
#multiplicação
2 * 2
# Out:
# 4

# %%
#divisão
10 / 2
# Out:
# 5.0

# %%
a = 4;
b = 6;

# %%
a + b
# Out:
# 10

# %%
#criando uma váriavel do tipo texto
frase = "Python para analise de dados"

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:10]
# Out:
# 'Python par'

# %%
frase[10:]
# Out:
# 'a analise de dados'

# %%
frase[:17]
# Out:
# 'Python para anali'

# %%
frase.count("dados")
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para analise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANALISE DE DADOS'

# %%
frase.replace("Python","Frases")
# Out:
# 'Frases para analise de dados'
