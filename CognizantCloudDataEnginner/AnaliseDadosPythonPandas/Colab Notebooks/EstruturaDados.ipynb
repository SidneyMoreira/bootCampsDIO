# %%
#criando uma lista de animais
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cachorro","gato",12345,6.5]
animais
# Out:
# ['cachorro', 'gato', 12345, 6.5]

# %%
#imprimindo o primeiro elemento da lista
animais[0]
# Out:
# 'cachorro'

# %%
#imprimindo o 4 elemento da lista
animais[3]
# Out:
# 6.5

# %%
#substituindo o primeiro elemento da lista
animais[0] ="papagaio"
animais
# Out:
# ['papagaio', 'gato', 12345, 6.5]

# %%
#removendo gato da lista
animais.remove("gato")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5]

# %%
lista = [50, 30, 300, 80, 10]

# %%
max(lista)
# Out:
# 300

# %%
min(lista)
# Out:
# 10

# %%
animais.append(["leão", "cachorro"])

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leão', 'cobra', 6, ['leão', 'cachorro']]

# %%
animais.extend(["cobra", 6])

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leão', 'cobra', 6, ['leão', 'cachorro']]

# %%
animais.count("leão")
# Out:
# 1

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 50, 80, 300]

# %% [markdown]
# # **Tuplas**

# %%
#as tuplas usam parenteses como sintaxe
tp = ("banana", "maça", 10, 50)

# %%
#retornando o primeiro elemento
tp[0]
# Out:
# 'banana'

# %%
#diferente das listas as tuplas são imutaveis, o que quer dizerque não podemos alterar os seus elementos
tp[0] = "laranja"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-b10c6622ad6b> in <module>()
#       1 #diferente das listas as tuplas são imutaveis, o que quer dizerque não podemos alterar os seus elementos
# ----> 2 tp[0] = "laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count("maça")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('banana', 'maça')

# %% [markdown]
# # **Dicionarios**

# %%
#para criar uma dicionario utilizamos {}
dc = {"maça":20,"banana":10,"laranja":15,"uva":5} #dicionarios trabalham com o conceito de chave e valor

# %%
dc
# Out:
# {'banana': 10, 'laranja': 15, 'maça': 20, 'uva': 5}

# %%
#acesso o valor de um dicionario atraves de chave
dc["maça"]
# Out:
# 20

# %%
#atualizando o valor de maça
dc["maça"] = 25
dc

# %%
#retornando todas as chaves de um dicionairo
dc.keys()
# Out:
# dict_keys(['maça', 'banana', 'laranja', 'uva'])

# %%
#retornando os valores de um dicionario
dc.values()
# Out:
# dict_values([25, 10, 15, 5])

# %%
#verificando se ja existe uma chave no dicionario e caso não existir inserir
dc.setdefault("limão",22)
# Out:
# 22

# %%
dc
# Out:
# {'banana': 10, 'laranja': 15, 'limão': 22, 'maça': 25, 'uva': 5}
